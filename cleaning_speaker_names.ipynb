# %%
# Import depdendencies
import pandas as pd
from sqlalchemy import create_engine

# %%
# Locate the file, read it into a pandas dataframe, and display the first few lines
office_lines_file = "Resource/cleaned_imdb_lines.csv"
office_lines_df = pd.read_csv(office_lines_file)
office_lines_df.head()
# Out:
#    Season  episode  Title  speaker  \
# 0       1        1  Pilot  Michael
# 1       1        1  Pilot      Jim
# 2       1        1  Pilot  Michael
# 3       1        1  Pilot      Jim
# 4       1        1  Pilot  Michael
#
#                                                 line
# 0  All right Jim. Your quarterlies look very good...
# 1         Oh, I told you. I couldn't close it. So...
# 2  So you've come to the master for guidance? Is ...
# 3         Actually, you called me in here, but yeah.
# 4    All right. Well, let me show you how it's done.

# %%
# Replace all the variations of names
office_lines_df["speaker"] = office_lines_df["speaker"].replace('"Angela"', 'Angela')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Angela:', 'Angela', regex=True)
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Anglea', 'Angela')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('AJ', 'A.J.')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('abe', 'Abe')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Andy:', 'Andy', regex=True)
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Andy & Erin', 'Andy and Erin')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Andy & Michael', 'Andy and Michael')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Bob', 'Bob Vance')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Bob Vance, Vance Refrigeration', 'Bob Vance')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Carla', 'Carla Fern')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Carol', 'Carol Stills')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Carrol', 'Carol Stills')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Carroll', 'Carol Stills')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Casey', 'Casey Dean')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Chares', 'Charles')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Creed:', 'Creed', regex=True)
office_lines_df["speaker"] = office_lines_df["speaker"].replace('D', 'Dwight')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Dacvid Walalce', 'David Wallace')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Dacvid Wallace', 'David Wallace')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('David Wallcve', 'David Wallace')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Dan', 'Dan Gore')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Darrly', 'Darryl')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Darry', 'Darryl')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Darryl:', 'Darryl', regex=True)
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Daryl', 'Darryl')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Darrly', 'Darryl')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('DeAgnelo', 'Deangelo')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Denagelo', 'Deangelo')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Deliveryman', 'Delivery man')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Diane', 'Diane Kelly')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Dight', 'Dwight')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Donna', 'Donna Muraski')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Dwight', 'Dwight')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Dwight & Andy', 'Dwight and Andy')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Dwight:', 'Dwight', regex=True)
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Dwight.', 'Dwight')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('DwightKSchrute', 'Dwight')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Erin:', 'Erin', regex=True)
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Everyone:', 'Everyone', regex=True)
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Everybody', 'Everyone')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Fred', 'Fred Henry')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Glen', 'Glenn')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Hide:', 'Hide', regex=True)
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Holy', 'Holly')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Walt Jr.', 'Walter Jr')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Stanley:', 'Stanley', regex=True)
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Stanely', 'Stanley')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Senator', 'Senator Lipton')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Senator Liptop', 'Senator Lipton')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Ryan:', 'Ryan', regex=True)
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Ryan Howard', 'Ryan')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Receptionitis*', 'Receptionist', regex=True)
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Phylis', 'Phyllis')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Phyliss', 'Phyllis')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Phyllis:', 'Phyllis', regex=True)
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Phil', 'Phil Maguire')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Philip', 'Phil Maguire')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Phillip', 'Phil Maguire')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Pam/Jim', 'Pam and Jim')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Pam:', 'Pam', regex=True)
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Pam [on phone]', 'Pam')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Pam as "fourth-biggest-client"', 'Pam')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Pam as "ninth-biggest-client"', 'Pam')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Pam', 'Pam')
office_lines_df["speaker"] = office_lines_df["speaker"].replace("Oscar's Computer", 'Oscar')
office_lines_df["speaker"] = office_lines_df["speaker"].replace("Oscar's voice from the computer", 'Oscar')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Oscar:', 'Oscar', regex=True)
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Mose [on phone]', 'Mose')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Micael', 'Michael')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Micahel', 'Michael')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Michae', 'Michael')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Michael', 'Michael')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Michael [on phone]', 'Michael')
office_lines_df["speaker"] = office_lines_df["speaker"].replace("Michael's Ad", 'Michael')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Michal', 'Michael')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Micheal', 'Michael')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Michael', 'Michael')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Michel', 'Michael')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Mihael', 'Michael')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Miichael', 'Michael')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Merv Bronte', 'Merv')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Meridith', 'Meredith')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Meredith:', 'Meredith', regex=True)
office_lines_df["speaker"] = office_lines_df["speaker"].replace('MeeMaw', 'Mee-Maw')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Matt:', 'Matt')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('M ichael', 'Michael')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Krasinski', 'Jim')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Kevin:', 'Kevin', regex=True)
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Kelly:', 'Kelly', regex=True)
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Julius Irving:', 'Julius', regex=True)
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Julie:', 'Julia', regex=True)
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Jo Bennett:', 'Jo', regex=True)
office_lines_df["speaker"] = office_lines_df["speaker"].replace('JIM9334*', 'JIM9334', regex=True)
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Jim', 'Jim')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Jim:', 'Jim', regex=True)
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Jim & Dwight', 'Jim and Dwight')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Michael/Dwight', 'Michael and Dwight')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Jim & Pam', 'Jim and Pam')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Jessica Alba', 'Jessica')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Jan [on phone])', 'Jan')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Isabel:', 'Isabel', regex=True)
office_lines_df["speaker"] = office_lines_df["speaker"].replace("Hunter's CD", 'Hunter')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Jim:', 'Jim', regex=True)
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Michael & Holly', 'Michael and Holly')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Pam & Jim', 'Jim and Pam')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Pam and Jim', 'Jim and Pam')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('Jim/Pam', 'Jim and Pam')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('"Jim"', 'Jim')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('"Jo"', 'Jo')
office_lines_df["speaker"] = office_lines_df["speaker"].replace('"Phyllis"', 'Phyllis')

# Export a clean file to use
office_lines_df.to_csv("Resource/office_lines_cleaned.csv",index=False)
